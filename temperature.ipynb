# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import urllib3
# %matplotlib inline

# %%
df= pd.read_csv("/Users/chiaentsai/Desktop/temperature.csv")

# %%
df
# Out:
#         date      8     10     12     14     16     18     20     22  \
# 0   2021/6/5    NaN    NaN    NaN    NaN    NaN  37.00  37.40  37.63
# 1   2021/6/6    NaN  37.00  36.80  37.23  37.07  37.13  37.00  37.03
# 2   2021/6/7  36.80  36.57  37.17  37.17  37.10  37.20  37.47  37.03
# 3   2021/6/8  36.80  36.98  37.60  37.37  37.43  37.23  37.40  37.17
# 4   2021/6/9    NaN  36.70  37.10  37.10  36.90  37.30  36.80  37.13
# 5  2021/6/10    NaN  36.77  37.07  37.17  36.80  37.17  36.77  37.00
# 6  2021/6/11  36.57  36.97    NaN    NaN    NaN    NaN    NaN    NaN
# 7  2021/6/12    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        average
# 0  37.34333333
# 1  37.03714286
# 2     37.06375
# 3      37.2475
# 4  37.00428571
# 5  36.96428571
# 6        36.77
# 7      #DIV/0!

# %%
df=df.drop(columns="8")

# %%
df
# Out:
#         date     10     12     14     16     18     20     22      average
# 0   2021/6/5    NaN    NaN    NaN    NaN  37.00  37.40  37.63  37.34333333
# 1   2021/6/6  37.00  36.80  37.23  37.07  37.13  37.00  37.03  37.03714286
# 2   2021/6/7  36.57  37.17  37.17  37.10  37.20  37.47  37.03     37.06375
# 3   2021/6/8  36.98  37.60  37.37  37.43  37.23  37.40  37.17      37.2475
# 4   2021/6/9  36.70  37.10  37.10  36.90  37.30  36.80  37.13  37.00428571
# 5  2021/6/10  36.77  37.07  37.17  36.80  37.17  36.77  37.00  36.96428571
# 6  2021/6/11  36.97    NaN    NaN    NaN    NaN    NaN    NaN        36.77
# 7  2021/6/12    NaN    NaN    NaN    NaN    NaN    NaN    NaN      #DIV/0!

# %%
df=df.dropna()

# %%
df
# Out:
#         date     10     12     14     16     18     20     22      average
# 1   2021/6/6  37.00  36.80  37.23  37.07  37.13  37.00  37.03  37.03714286
# 2   2021/6/7  36.57  37.17  37.17  37.10  37.20  37.47  37.03     37.06375
# 3   2021/6/8  36.98  37.60  37.37  37.43  37.23  37.40  37.17      37.2475
# 4   2021/6/9  36.70  37.10  37.10  36.90  37.30  36.80  37.13  37.00428571
# 5  2021/6/10  36.77  37.07  37.17  36.80  37.17  36.77  37.00  36.96428571

# %%
plt.plot(df["date"],df["10"],linestyle='solid',color='blue',label="10")
plt.plot(df["date"],df["12"],linestyle='solid',color='red',label="12")
plt.plot(df["date"],df["14"],linestyle='solid',color='yellow',label="14")
plt.plot(df["date"],df["16"],linestyle='solid',color='green',label="16")
plt.plot(df["date"],df["18"],linestyle='solid',color='black',label="18")
plt.plot(df["date"],df["20"],linestyle='solid',color='orange',label="20")
plt.legend()

# %%
plt.scatter(df["date"],df["average"],linestyle='solid',color='purple')
plt.gca().invert_yaxis()
